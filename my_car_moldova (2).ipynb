# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd # Библиотека Pandas для работы с табличными данными
from google.colab import files  # чтобы загружать файлы в облако через проводник 

import numpy as np # библиотека Numpy для операций линейной алгебры и прочего
import matplotlib.pyplot as plt # библиотека MatPlotLib для визуализации
import seaborn as sns;

# %% [markdown]
# # New Section

# %%
df = pd.read_csv('/content/cars_moldova_clean.csv', delimiter = ',')
df
# Out:
#              Make         Model  Year      Style  Distance  \
# 0          Toyota         Prius  2011  Hatchback  195000.0
# 1         Renault  Grand Scenic  2014  Universal  135000.0
# 2         Renault        Laguna  2012  Universal  110000.0
# 3            Opel         Astra  2006  Universal  200000.0
# 4        Mercedes          Vito  2000   Microvan  300000.0
# ...           ...           ...   ...        ...       ...
# 32215  Volkswagen        Passat  2016      Sedan   88000.0
# 32216  Land Rover    Freelander  2002  Crossover  225000.0
# 32217       Dacia     Logan Mcv  2015  Universal   89000.0
# 32218       Mazda             6  2006      Combi  370000.0
# 32219     Renault  Grand Scenic  2006    Minivan  300000.0
#
#        Engine_capacity(cm3)     Fuel_type Transmission  Price(euro)  Age  \
# 0                    1800.0        Hybrid    Automatic       7750.0   11
# 1                    1500.0        Diesel       Manual       8550.0    8
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32220 entries, 0 to 32219
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Make                  32220 non-null  object
#  1   Model                 32220 non-null  object
#  2   Year                  32220 non-null  int64
#  3   Style                 32220 non-null  object
#  4   Distance              32220 non-null  float64
#  5   Engine_capacity(cm3)  32220 non-null  float64
#  6   Fuel_type             32220 non-null  object
#  7   Transmission          32220 non-null  object
#  8   Price(euro)           32220 non-null  float64
#  9   Age                   32220 non-null  int64
#  10  km_year               32220 non-null  float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 2.7+ MB

# %%
df[df.duplicated()]
# Out:
#              Make Model  Year      Style  Distance  Engine_capacity(cm3)  \
# 1800        Dacia  Rare  2015  Universal  195200.0                1500.0
# 6203         Mini  Rare  2013  Cabriolet   89000.0                1600.0
# 12623      Jaguar  Rare  2011      Sedan   76000.0                3000.0
# 13166      Toyota  Rare  2015  Universal  240000.0                1798.0
# 14854       Dacia  Rare  2013    Minivan  165000.0                1500.0
# 16171      Jaguar  Rare  2017      Sedan   33000.0                2000.0
# 20207  Alfa Romeo  Rare  2011  Hatchback  122000.0                1400.0
# 21501    Mercedes  Rare  2006      Sedan  186543.0                4800.0
# 24136        Jeep  Rare  2002        SUV  169422.0                2500.0
# 24969        Mini  Rare  2009      Coupe  180000.0                1397.0
# 29557        Mini  Rare  2004      Coupe  300000.0                1400.0
#
#       Fuel_type Transmission  Price(euro)  Age       km_year
# ...

# %%
df.drop_duplicates() #удаление повторяющихся значений
df.shape
# Out:
# (32220, 11)

# %%
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Style                   0
# Distance                0
# Engine_capacity(cm3)    0
# Fuel_type               0
# Transmission            0
# Price(euro)             0
# Age                     0
# km_year                 0
# dtype: int64

# %% [markdown]
# визуализируем пропушенны значения

# %%
colours=["red","yellow"]
sns.heatmap(df.isnull(),snap=sns.color_palette(colours),cbar=False);

# %%
for column in df.columns:
  print(df[column].unique().tolist())
# Out:
# ['Toyota', 'Renault', 'Opel', 'Mercedes', 'Volkswagen', 'BMW', 'Volvo', 'Nissan', 'Hyundai', 'Audi', 'GAZ', 'Rare', 'Lincoln', 'Lexus', 'Dodge', 'Porsche', 'Dacia', 'Peugeot', 'Ford', 'Vaz', 'Honda', 'Skoda', 'Mazda', 'Chevrolet', 'Citroen', 'Jaguar', 'Infiniti', 'Land Rover', 'KIA', 'Seat', 'Mitsubishi', 'Fiat', 'Suzuki', 'Daewoo', 'Subaru', 'Mini', 'Rover', 'Chrysler', 'Jeep', 'Smart', 'Moskvich / Izh', 'Alfa Romeo', 'Daihatsu', 'Ssangyong']
# ...

# %% [markdown]
#  категориальные и численные столбцы

# %%
 df.select_dtypes(include=[np.number])
 df.select_dtypes(exclude=[np.number])

display(df.select_dtypes(include=[np.number]).shape[1])
display(df.select_dtypes(exclude=[np.number]).shape[1])
# Out:
# 6
# 5

# %%
df.select_dtypes(exclude=[np.number]).columns
# Out:
# Index(['Make', 'Model', 'Style', 'Fuel_type', 'Transmission'], dtype='object')

# %%
df.select_dtypes(include=[np.number]).columns
# Out:
# Index(['Year', 'Distance', 'Engine_capacity(cm3)', 'Price(euro)', 'Age',
#        'km_year'],
#       dtype='object')

# %%
def error_cal(rank :str):
    try:
        return str(rank) 
    except:
        return np.nan

# %%
for column in df.select_dtypes(exclude=[np.number]).columns:
  df[column]=pd.Series(map(error_cal,df[column]))

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def get_model(x):
    if x.isdigit()==True:
        return np.nan
    else:
        return x
df["Model"]=df["Model"].apply(get_model)

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.isna().transpose());

# %% [markdown]
# заполнение пустот с использованием метода к ближайших соседей(knn)

# %%
from sklearn.impute import KNNImputer
from sklearn.cluster import DBSCAN

# %%
df.Model.shape
# Out:
# (32220,)

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='most_frequent',missing_values=np.nan)
imputer.fit(df[['Model']])
# Out:
# SimpleImputer(strategy='most_frequent')

# %%
df['Model'] = imputer.transform(df[['Model']])

# %%
df.Model.isna().sum()
# Out:
# 0

# %% [markdown]
# https://towardsdatascience.com/imputing-missing-values-using-the-simpleimputer-class-in-sklearn-99706afaff46

# %%
df.Model.shape
# Out:
# (32220,)

# %%
#from sklearn.impute import KNNImputer
#from sklearn.cluster import DBSCAN
#imputer=KNNImputer(n_neighbors=5,weights="uniform")
#imputer.fit(df.Model)

# %%
df.describe()
# Out:
#                Year        Distance  Engine_capacity(cm3)    Price(euro)  \
# count  32220.000000    32220.000000          32220.000000   32220.000000
# mean    2008.293172   182513.687430           1868.610273    9454.779733
# std        7.189603    96805.552427            609.781322    9519.612235
# min     1971.000000      100.000000            200.000000     200.000000
# 25%     2005.000000   123000.000000           1500.000000    3599.000000
# 50%     2010.000000   180000.000000           1800.000000    6730.500000
# 75%     2014.000000   237000.000000           2000.000000   12000.000000
# max     2021.000000  1000000.000000           5000.000000  100000.000000
#
#                 Age       km_year
# count  32220.000000  32220.000000
# mean      13.706828  14954.229373
# std        7.189603   7337.012277
# min        1.000000    100.000000
# 25%        8.000000  10271.827206
# 50%       12.000000  14461.538462
# 75%       17.000000  18888.888889
# ...

# %%
pd.set_option('display.float_format', lambda x: '%0.4f' % x)

# %%
df.describe()
# Out:
#             Year     Distance  Engine_capacity(cm3)  Price(euro)        Age  \
# count 32220.0000   32220.0000            32220.0000   32220.0000 32220.0000
# mean   2008.2932  182513.6874             1868.6103    9454.7797    13.7068
# std       7.1896   96805.5524              609.7813    9519.6122     7.1896
# min    1971.0000     100.0000              200.0000     200.0000     1.0000
# 25%    2005.0000  123000.0000             1500.0000    3599.0000     8.0000
# 50%    2010.0000  180000.0000             1800.0000    6730.5000    12.0000
# 75%    2014.0000  237000.0000             2000.0000   12000.0000    17.0000
# max    2021.0000 1000000.0000             5000.0000  100000.0000    51.0000
#
#          km_year
# count 32220.0000
# mean  14954.2294
# std    7337.0123
# min     100.0000
# 25%   10271.8272
# 50%   14461.5385
# 75%   18888.8889
# max   50000.0000

# %%
df.describe(include="object")
# Out:
#               Make  Model  Style Fuel_type Transmission
# count        32220  32220  32220     32220        32220
# unique          44    126     12         6            2
# top     Volkswagen   Rare  Sedan    Diesel       Manual
# freq          3423   7299   9763     15288        17520

# %%
#Построим корреляционную матрицу
fig, ax = plt.subplots(figsize=(15,7))
sns.heatmap(df.corr(method='pearson'), ax=ax, annot=True, fmt='.2f')

# %% [markdown]
# Как визуально определить, является ли распределение нормальным?
#
# Гистограмма распределения.
#
# График квантиль-квантиль или Q-Q plot.

# %%
import scipy.stats as stats

# %%
def diagnostic_plots(df, variable):
    plt.figure(figsize=(15,6))
    # гистограмма
    plt.subplot(1, 2, 1)
    df[variable].hist(bins=30)
    ## Q-Q plot
    plt.subplot(1, 2, 2)
    stats.probplot(df[variable], dist="norm", plot=plt)
    plt.show()

# %%
df.hist(figsize=(15,5))
plt.show()

# %%
diagnostic_plots(df, 'Engine_capacity(cm3)')

# %% [markdown]
# категориальные и численные столбцы

# %%
 num_columns=df.select_dtypes(include=[np.number])
 cat_columns=df.select_dtypes(exclude=[np.number])

# %%
fig, ax = plt.subplots(nrows=6, ncols=1, figsize=(10,20))

for idx, column_name in enumerate(num_columns):

    plt.subplot(6,1, idx+1)
    sns.boxplot(data=df,
            x=column_name);

# %%
question_dist = df[(df.Distance > 0.5e6)]
df = df.drop(question_dist.index)

df = df.reset_index(drop=True)

fig, ax = plt.subplots(nrows=6, ncols=1, figsize=(10,20))

for idx, column_name in enumerate(num_columns):

    plt.subplot(6,1, idx+1)
    sns.boxplot(data=df,
            x=column_name);

# %%
df[df.Distance==df.Distance.max()].head()
# Out:
#         Make     Model  Year      Style    Distance  Engine_capacity(cm3)  \
# 1030  Toyota   Corolla  1993  Universal 500000.0000             1600.0000
# 3428   Skoda    Superb  2003      Sedan 500000.0000             1800.0000
# 5732   Skoda     Fabia  2000  Hatchback 500000.0000             1400.0000
# 7426     BMW  5 Series  1996      Sedan 500000.0000             2000.0000
# 8142     BMW  7 Series  1996      Sedan 500000.0000             2800.0000
#
#          Fuel_type Transmission  Price(euro)  Age    km_year
# 1030  Metan/Propan       Manual    1500.0000   29 17241.3793
# 3428  Metan/Propan       Manual    3500.0000   19 26315.7895
# 5732        Petrol       Manual    2000.0000   22 22727.2727
# 7426        Petrol       Manual    2500.0000   26 19230.7692
# 8142  Metan/Propan    Automatic    3500.0000   26 19230.7692

# %%
#пака выброси оставым отдельно ,если качества модели ни очень хорошо тогда изучаем отдельно

# %%
df[df.Distance==df.Distance.min()]
# Out:
#       Make     Model  Year      Style  Distance  Engine_capacity(cm3)  \
# 20776  KIA      Rare  2021    Minivan  100.0000             2151.0000
# 21150  KIA  Sportage  2021  Crossover  100.0000             1598.0000
# 27657  KIA      Rare  2021    Minivan  100.0000             2151.0000
#
#       Fuel_type Transmission  Price(euro)  Age  km_year
# 20776    Diesel    Automatic   41099.0000    1 100.0000
# 21150    Petrol    Automatic   30899.0000    1 100.0000
# 27657    Diesel    Automatic   34299.0000    1 100.0000

# %%
cm = sns.color_palette("vlag", as_cmap=True)
df.corr().style.background_gradient(cmap=cm, vmin = -1, vmax=1)
# Out:
# <style type="text/css">
# #T_36449_row0_col0, #T_36449_row1_col1, #T_36449_row2_col2, #T_36449_row3_col3, #T_36449_row4_col4, #T_36449_row5_col5 {
#   background-color: #a9373b;
#   color: #f1f1f1;
# }
# #T_36449_row0_col1, #T_36449_row1_col0 {
#   background-color: #a8b7cf;
#   color: #000000;
# }
# #T_36449_row0_col2, #T_36449_row2_col0 {
#   background-color: #f9f5f5;
#   color: #000000;
# }
# #T_36449_row0_col3, #T_36449_row3_col0 {
#   background-color: #cf8e8b;
#   color: #f1f1f1;
# }
# #T_36449_row0_col4, #T_36449_row4_col0 {
#   background-color: #2369bd;
#   color: #f1f1f1;
# }
# #T_36449_row0_col5, #T_36449_row5_col0 {
#   background-color: #d8a3a0;
#   color: #000000;
# }
# #T_36449_row1_col2, #T_36449_row2_col1 {
#   background-color: #f8edeb;
#   color: #000000;
# }
# #T_36449_row1_col3, #T_36449_row3_col1 {
#   background-color: #b8c3d5;
#   color: #000000;
# }
# #T_36449_row1_col4, #T_36449_row4_col1 {
#   background-color: #d9a5a2;
#   color: #000000;
# }
# ...

# %%
popular_Model =df.Model.value_counts().nlargest(10).index
print(popular_Model)
# Out:
# Index(['Rare', 'E Class', '5 Series', 'Passat', 'Megane', 'Astra', 'Golf',
#        'Octavia', 'Auris', 'Qashqai'],
#       dtype='object')

# %%
gb = df[df.Model.isin(popular_Model)].groupby(['Model'])[['Engine_capacity(cm3)',"Price(euro)"]].mean().sort_values(
    by=["Engine_capacity(cm3)","Price(euro)"],
    ascending=[False, False]
    ).reset_index()
# Рисуем!
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(15, 10))

# столбчатая диаграмма
axes[0].bar(
    x=gb["Model"],
    height=gb["Price(euro)"],
)
axes[0].set_title("price")
axes[0].xaxis.set_tick_params(rotation=45)


axes[1].bar(
    x=gb["Model"],
    height=gb["Engine_capacity(cm3)"],
    color="tomato",
    lw=2,
)
axes[1].set_title("engine")
axes[1].xaxis.set_tick_params(rotation=45)

# %%
plt.figure(figsize=(20,10))
sns.barplot(data=df, x="Year", y="Price(euro)",hue="Transmission")

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df, x="Year", y="Price(euro)",hue="Transmission")

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df, x="Year", y="Price(euro)",hue="Fuel_type")

# %%
popular_make =df.Make.value_counts().nlargest(10).index
print(popular_make)
# Out:
# Index(['Volkswagen', 'Toyota', 'Mercedes', 'BMW', 'Renault', 'Opel', 'Skoda',
#        'Audi', 'Ford', 'Dacia'],
#       dtype='object')

# %%
gb = df.groupby(['Make','Age'])["Price(euro)"].mean().sort_values(
  
    ascending=False
    ).reset_index()[:20]
gb
# Out:
#           Make  Age  Price(euro)
# 0   Land Rover    1   99000.0000
# 1      Porsche    2   81672.5000
# 2      Porsche    3   72537.8000
# 3   Land Rover    3   71500.0000
# 4        Volvo    1   69500.0000
# 5   Land Rover    2   67599.6667
# 6   Land Rover    4   63010.2632
# 7      Porsche    4   58528.4706
# 8      Porsche    5   58234.4615
# 9          BMW    2   56841.4583
# 10        Audi    3   52373.2000
# 11    Mercedes    2   51599.7059
# 12       Volvo    2   49216.1667
# 13  Land Rover    5   48225.0000
# 14     Porsche    6   47798.3889
# 15         BMW    1   46238.0000
# 16         BMW    3   45986.9032
# 17    Mercedes    1   45441.5000
# 18      Jaguar    8   44999.3333
# 19        Jeep    3   44400.0000

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=gb, x="Age", y="Price(euro)",hue="Make")

# %%
popular_make =df.Make.value_counts().nlargest(5).index
print(popular_make)
# Out:
# Index(['Volkswagen', 'Toyota', 'Mercedes', 'BMW', 'Renault'], dtype='object')

# %%
gb1=df[df.Make.isin(popular_make)].groupby(['Make','Age'],as_index=False)["Price(euro)"].mean()
gb1
# Out:
#            Make  Age  Price(euro)
# 0           BMW    1   46238.0000
# 1           BMW    2   56841.4583
# 2           BMW    3   45986.9032
# 3           BMW    4   36742.0448
# 4           BMW    5   33058.5484
# ..          ...  ...          ...
# 191  Volkswagen   39    4999.0000
# 192  Volkswagen   40     682.0000
# 193  Volkswagen   41     975.0000
# 194  Volkswagen   42     500.0000
# 195  Volkswagen   44    1000.0000
#
# [196 rows x 3 columns]

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=gb1, x="Age", y="Price(euro)",hue="Make")

# %%
df1=df.copy()
df1.drop("Year",axis=1,inplace=True)

# %%
plt.figure(figsize=(10,10))
sns.pairplot(df1, kind="scatter", hue = "Transmission")
sns.set_palette("dark")

# %%
plt.figure(figsize=(10,10))
data = df1
sns.pairplot(data.select_dtypes(include=[int, float]), hue="Price(euro)",palette='CMRmap')

# %%
df1.head()
# Out:
#        Make         Model      Style    Distance  Engine_capacity(cm3)  \
# 0    Toyota         Prius  Hatchback 195000.0000             1800.0000
# 1   Renault  Grand Scenic  Universal 135000.0000             1500.0000
# 2   Renault        Laguna  Universal 110000.0000             1500.0000
# 3      Opel         Astra  Universal 200000.0000             1600.0000
# 4  Mercedes          Vito   Microvan 300000.0000             2200.0000
#
#       Fuel_type Transmission  Price(euro)  Age    km_year
# 0        Hybrid    Automatic    7750.0000   11 17727.2727
# 1        Diesel       Manual    8550.0000    8 16875.0000
# 2        Diesel       Manual    6550.0000   10 11000.0000
# 3  Metan/Propan       Manual    4100.0000   16 12500.0000
# 4        Diesel       Manual    3490.0000   22 13636.3636

# %%
df1['Price(euro)'].describe()
# Out:
# count    32074.0000
# mean      9479.1877
# std       9531.5458
# min        200.0000
# 25%       3600.0000
# 50%       6799.0000
# 75%      12075.2500
# max     100000.0000
# Name: Price(euro), dtype: float64

# %%
#f1[df1['Price(euro)'].between(200, 1000, 'both')==True].head()
df1[df1['Price(euro)'].between(200, 1000, inclusive=True)].head()
# Out:
#            Make   Model      Style    Distance  Engine_capacity(cm3)  \
# 158      Nissan  Almera  Hatchback  90000.0000             1500.0000
# 170    Mercedes    Rare  Universal 100000.0000             2400.0000
# 285  Volkswagen    Polo  Hatchback  98000.0000             1000.0000
# 338       Skoda   Fabia  Hatchback 230000.0000             1400.0000
# 452  Volkswagen    Golf  Hatchback  11111.0000             1600.0000
#
#     Fuel_type Transmission  Price(euro)  Age    km_year
# 158    Petrol       Manual    1000.0000   19  4736.8421
# 170    Diesel       Manual    1000.0000   38  2631.5789
# 285    Petrol       Manual     900.0000   24  4083.3333
# 338    Petrol       Manual     950.0000   20 11500.0000
# 452    Petrol       Manual     800.0000   27   411.5185

# %%
def get_class(x):
  if  x in df1['Price(euro)'][df1['Price(euro)'].between(200, 1000, inclusive=True)].unique():
    return 1
  if  x in df1['Price(euro)'][df1['Price(euro)'].between(1000, 3000, inclusive=True)].unique():
    return 2
  if  x in df1['Price(euro)'][df1['Price(euro)'].between(3000, 7000, inclusive=True)].unique():
    return 3
  if  x in df1['Price(euro)'][df1['Price(euro)'].between(7000, 12000, inclusive=True)].unique():
    return 4
  else:
    return 5  
df1["class"]=df1["Price(euro)"].apply(get_class)

# %%
df1.head()
# Out:
#        Make         Model      Style    Distance  Engine_capacity(cm3)  \
# 0    Toyota         Prius  Hatchback 195000.0000             1800.0000
# 1   Renault  Grand Scenic  Universal 135000.0000             1500.0000
# 2   Renault        Laguna  Universal 110000.0000             1500.0000
# 3      Opel         Astra  Universal 200000.0000             1600.0000
# 4  Mercedes          Vito   Microvan 300000.0000             2200.0000
#
#       Fuel_type Transmission  Price(euro)  Age    km_year  class
# 0        Hybrid    Automatic    7750.0000   11 17727.2727      4
# 1        Diesel       Manual    8550.0000    8 16875.0000      4
# 2        Diesel       Manual    6550.0000   10 11000.0000      3
# 3  Metan/Propan       Manual    4100.0000   16 12500.0000      3
# 4        Diesel       Manual    3490.0000   22 13636.3636      3

# %%
pd.cut(df1['Price(euro)'], bins=10).value_counts()
# Out:
# (100.2, 10180.0]       22148
# (10180.0, 20160.0]      7081
# (20160.0, 30140.0]      1699
# (30140.0, 40120.0]       617
# (40120.0, 50100.0]       254
# (50100.0, 60080.0]       119
# (60080.0, 70060.0]        71
# (70060.0, 80040.0]        41
# (80040.0, 90020.0]        22
# (90020.0, 100000.0]       22
# Name: Price(euro), dtype: int64

# %%
plt.figure(figsize=(15,8))
sns.histplot(data=df1,
            x="Price(euro)",
            hue='class',
            palette='dark',
            bins=10)

# %%
print("самые престижные марки: ",df1.loc[df1['class']==5 ,'Make'].unique())
# Out:
# самые престижные марки:  ['Volkswagen' 'Volvo' 'Rare' 'Mercedes' 'Lincoln' 'Lexus' 'Porsche' 'BMW'
#  'Peugeot' 'Honda' 'Nissan' 'Skoda' 'Toyota' 'Audi' 'Jaguar' 'Ford'
#  'Renault' 'Infiniti' 'KIA' 'Mazda' 'Land Rover' 'Hyundai' 'Chevrolet'
#  'Suzuki' 'Opel' 'Mitsubishi' 'Dacia' 'Citroen' 'Vaz' 'Seat' 'Jeep'
#  'Ssangyong' 'Mini' 'Dodge' 'Subaru' 'Fiat' 'GAZ' 'Chrysler' 'Alfa Romeo'
#  'Rover' 'Moskvich / Izh']

# %%
print("самые непрестижные марки: ",df1.loc[df1['class']==1 ,'Make'].unique())
# Out:
# самые непрестижные марки:  ['Nissan' 'Mercedes' 'Volkswagen' 'Skoda' 'Daewoo' 'Ford' 'Opel' 'Vaz'
#  'BMW' 'Rare' 'Renault' 'Mazda' 'KIA' 'Audi' 'Volvo' 'Honda' 'Mitsubishi'
#  'Peugeot' 'Suzuki' 'GAZ' 'Toyota' 'Fiat' 'Hyundai' 'Ssangyong' 'Seat'
#  'Citroen' 'Dacia' 'Rover' 'Moskvich / Izh' 'Chrysler' 'Chevrolet' 'Jeep'
#  'Daihatsu' 'Subaru' 'Jaguar']

# %%
#второй вориант

# %%
gb1=df1.groupby(['Age'],as_index=False)[["Price(euro)",'class']].median()
gb1.head()
# Out:
#    Age  Price(euro)  class
# 0    1   29699.0000 5.0000
# 1    2   31000.0000 5.0000
# 2    3   24300.0000 5.0000
# 3    4   18900.0000 5.0000
# 4    5   15799.0000 5.0000

# %%
df1['Price(euro)'].quantile(0.75)
# Out:
# 12075.25

# %%
def get_prestige(x):
  if  x > df1['Price(euro)'].quantile(0.75) :
    return 1
  if  (x < df1['Price(euro)'].quantile(0.75)) & (x > df1['Price(euro)'].quantile(0.5)) :
    return 2
  if  (x < df1['Price(euro)'].quantile(0.5)) & (x > df1['Price(euro)'].quantile(0.25)) :
    return 3
  else :
    return 4
df1["prestige"]=df1["Price(euro)"].apply(get_prestige)

# %%
plt.figure(figsize=(15,8))
sns.histplot(data=df1,
            x="Price(euro)",
            hue='prestige',
            palette='dark',
            bins=10)

# %%
df1.head()
# Out:
#        Make         Model      Style    Distance  Engine_capacity(cm3)  \
# 0    Toyota         Prius  Hatchback 195000.0000             1800.0000
# 1   Renault  Grand Scenic  Universal 135000.0000             1500.0000
# 2   Renault        Laguna  Universal 110000.0000             1500.0000
# 3      Opel         Astra  Universal 200000.0000             1600.0000
# 4  Mercedes          Vito   Microvan 300000.0000             2200.0000
#
#       Fuel_type Transmission  Price(euro)  Age    km_year  class  prestige
# 0        Hybrid    Automatic    7750.0000   11 17727.2727      4         2
# 1        Diesel       Manual    8550.0000    8 16875.0000      4         2
# 2        Diesel       Manual    6550.0000   10 11000.0000      3         3
# 3  Metan/Propan       Manual    4100.0000   16 12500.0000      3         3
# 4        Diesel       Manual    3490.0000   22 13636.3636      3         4

# %%
print("самые престижные марки: ",df1.loc[df1.prestige==1 ,'Make'].unique())
# Out:
# самые престижные марки:  ['Volkswagen' 'Volvo' 'Rare' 'Mercedes' 'Lincoln' 'Lexus' 'Porsche' 'BMW'
#  'Peugeot' 'Honda' 'Nissan' 'Skoda' 'Toyota' 'Audi' 'Jaguar' 'Ford'
#  'Renault' 'Infiniti' 'KIA' 'Mazda' 'Land Rover' 'Hyundai' 'Chevrolet'
#  'Suzuki' 'Opel' 'Mitsubishi' 'Dacia' 'Citroen' 'Vaz' 'Seat' 'Jeep'
#  'Ssangyong' 'Mini' 'Dodge' 'Subaru' 'Fiat' 'GAZ' 'Chrysler' 'Alfa Romeo'
#  'Rover' 'Moskvich / Izh']

# %%
print("самые  непрестижные марки: ",df1.loc[df1.prestige==4 ,'Make'].unique())
# Out:
# самые  непрестижные марки:  ['Mercedes' 'BMW' 'Hyundai' 'GAZ' 'Audi' 'Opel' 'Volkswagen' 'Renault'
#  'Vaz' 'Toyota' 'Land Rover' 'KIA' 'Seat' 'Honda' 'Fiat' 'Daewoo' 'Nissan'
#  'Peugeot' 'Dacia' 'Rare' 'Citroen' 'Mitsubishi' 'Skoda' 'Rover' 'Volvo'
#  'Ford' 'Chevrolet' 'Mazda' 'Jeep' 'Suzuki' 'Smart' 'Moskvich / Izh'
#  'Alfa Romeo' 'Chrysler' 'Mini' 'Daihatsu' 'Ssangyong' 'Dodge' 'Subaru'
#  'Lincoln' 'Porsche' 'Lexus' 'Jaguar' 'Infiniti']

# %% [markdown]
# при отчасти результаты по стоимости,одинаковие марки попали как в престижние так и непрестижние

# %% [markdown]
# Многие модели машинного обучения лучше работают с нормализованными признаками, особенно линейные модели.
#
# Какие функции чаще всего используются для нормализации:
#
# логарифм - np.log(X)
# обратная зависимость - 1 / X
# квадратный корень
# возведение в степень

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
 num_col=df1.select_dtypes(include=[np.number])
 cat_col=df1.select_dtypes(exclude=[np.number])

# %%
#построим ящики с усами для нестандартизованных данных
fig = plt.figure(figsize=(20,5))
ax = fig.add_axes([0,0,1,1])
ax.set_xticklabels(num_col.columns)


data = [ ]

for col in num_col.columns:
    data.append(num_col[col])

bp=ax.boxplot(data,widths=0.5)
plt.show();

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(num_col)
# Out:
# StandardScaler()

# %%
num_std = pd.DataFrame(scaler.transform(num_col), columns=num_col.columns)
num_std
# Out:
#        Distance  Engine_capacity(cm3)  Price(euro)     Age  km_year   class  \
# 0        0.1624               -0.1124      -0.1814 -0.3719   0.3923  0.4483
# 1       -0.5003               -0.6043      -0.0975 -0.7908   0.2748  0.4483
# 2       -0.7764               -0.6043      -0.3073 -0.5115  -0.5354 -0.4364
# 3        0.2176               -0.4403      -0.5644  0.3261  -0.3285 -0.4364
# 4        1.3221                0.5436      -0.6284  1.1638  -0.1718 -0.4364
# ...         ...                   ...          ...     ...      ...     ...
# 32069   -1.0194               -0.1124       0.2120 -1.0700  -0.0298  0.4483
# 32070    0.4937               -0.1124      -0.5329  0.8846  -0.5009 -0.4364
# 32071   -1.0084               -0.6043      -0.2601 -0.9304  -0.2990 -0.4364
# 32072    2.0952                0.2156      -0.5749  0.3261   1.1366 -0.4364
# 32073    1.3221               -0.6043      -0.5749  0.3261   0.5333 -0.4364
#
#        prestige
# 0       -0.4508
# 1       -0.4508
# ...

# %%
pd.set_option('display.float_format', lambda x: '%0.4f' % x)
num_std.describe()
# Out:
#         Distance  Engine_capacity(cm3)  Price(euro)        Age    km_year  \
# count 32074.0000            32074.0000   32074.0000 32074.0000 32074.0000
# mean     -0.0000               -0.0000      -0.0000    -0.0000    -0.0000
# std       1.0000                1.0000       1.0000     1.0000     1.0000
# min      -1.9903               -2.7361      -0.9735    -1.7681    -2.0385
# 25%      -0.6328               -0.6043      -0.6168    -0.7908    -0.6388
# 50%      -0.0033               -0.1124      -0.2812    -0.2323    -0.0621
# 75%       0.6081                0.2156       0.2724     0.4657     0.5402
# max       3.5311                5.1351       9.4971     5.2126     4.8427
#
#            class   prestige
# count 32074.0000 32074.0000
# mean     -0.0000     0.0000
# std       1.0000     1.0000
# min      -2.2060    -1.3418
# 25%      -0.4364    -1.1191
# 50%      -0.4364     0.4403
# 75%       1.3331     1.3313
# max       1.3331     1.3313

# %%
for column in num_std.columns:    
  diagnostic_plots(num_std, column)

# %%
from sklearn import preprocessing as prep

# %%
scaler1=prep.PowerTransformer()
scaler1.fit(num_std)
# Out:
# PowerTransformer()

# %%
num_std_power = pd.DataFrame(scaler1.transform(num_std), columns=num_std.columns)
num_std_power
# Out:
#        Distance  Engine_capacity(cm3)  Price(euro)     Age  km_year   class  \
# 0        0.2068                0.0099       0.1632 -0.2351   0.4672  0.4259
# 1       -0.4714               -0.5725       0.3061 -0.8113   0.3559  0.4259
# 2       -0.7669               -0.5725      -0.0786 -0.4175  -0.4906 -0.4608
# 3        0.2610               -0.3692      -0.6795  0.5188  -0.2610 -0.4608
# 4        1.2936                0.6531      -0.8524  1.1746  -0.0928 -0.4608
# ...         ...                   ...          ...     ...      ...     ...
# 32069   -1.0320                0.0099       0.7183 -1.2413   0.0550  0.4259
# 32070    0.5276                0.0099      -0.5979  0.9752  -0.4518 -0.4608
# 32071   -1.0198               -0.5725       0.0160 -1.0219  -0.2289 -0.4608
# 32072    1.9764                0.3486      -0.7072  0.5188   1.1260 -0.4608
# 32073    1.2936               -0.5725      -0.7072  0.5188   0.5976 -0.4608
#
#        prestige
# 0       -0.4520
# 1       -0.4520
# ...

# %%
num_std_power.describe()
# Out:
#         Distance  Engine_capacity(cm3)  Price(euro)        Age    km_year  \
# count 32074.0000            32074.0000   32074.0000 32074.0000 32074.0000
# mean     -0.0000               -0.0000       0.0000    -0.0000    -0.0000
# std       1.0000                1.0000       1.0000     1.0000     1.0000
# min      -2.1290               -3.8422      -1.9533    -2.4617    -2.3571
# 25%      -0.6124               -0.5725      -0.8205    -0.8113    -0.6084
# 50%       0.0420                0.0099      -0.0256    -0.0630     0.0218
# 75%       0.6362                0.3486       0.7821     0.6418     0.6039
# max       3.1899                3.6161       2.6879     3.1657     3.8342
#
#            class   prestige
# count 32074.0000 32074.0000
# mean     -0.0000    -0.0000
# std       1.0000     1.0000
# min      -2.1154    -1.3406
# 25%      -0.4608    -1.1184
# 50%      -0.4608     0.4390
# 75%       1.3604     1.3326
# max       1.3604     1.3326

# %%
for column in num_std.columns:    
  diagnostic_plots(num_std_power, column)

# %% [markdown]
# cтандартизируем данные чтобы избежать влияния размерности

# %%
#построим ящики с усами для стандартизованных данных
fig = plt.figure(figsize=(20,5))
ax = fig.add_axes([0,0,1,1])
ax.set_xticklabels(num_std.columns)

data = [ ]

for col in num_std.columns:
    data.append(num_std[col])

bp=ax.boxplot(data,widths=0.5)
plt.show();

# %%
mins = num_col.min()
maxs = num_col.max()

# %%
num_norm = (num_col - mins) / (maxs - mins)
num_norm.describe()
# Out:
#         Distance  Engine_capacity(cm3)  Price(euro)        Age    km_year  \
# count 32074.0000            32074.0000   32074.0000 32074.0000 32074.0000
# mean      0.3605                0.3476       0.0930     0.2533     0.2962
# std       0.1811                0.1270       0.0955     0.1433     0.1453
# min       0.0000                0.0000       0.0000     0.0000     0.0000
# 25%       0.2458                0.2708       0.0341     0.1400     0.2034
# 50%       0.3599                0.3333       0.0661     0.2200     0.2872
# 75%       0.4706                0.3750       0.1190     0.3200     0.3747
# max       1.0000                1.0000       1.0000     1.0000     1.0000
#
#            class   prestige
# count 32074.0000 32074.0000
# mean      0.6233     0.5020
# std       0.2826     0.3741
# min       0.0000     0.0000
# 25%       0.5000     0.0833
# 50%       0.5000     0.6667
# 75%       1.0000     1.0000
# max       1.0000     1.0000

# %% [markdown]
# Вот мы и разобрались, зачем нужно масштабирование данных и как его применять.
#
# Масштабирование данных нужно для более стабильного обучения модели.
# Есть два основных вида масштабирование
#
#
# Нормализация
# После min = 0, max = 1 у всех признаков
# Подход лучше зарекомендовал себя в подходах МЛ, которые работают с расстояниями (KNN)
#
#
#
# Стандартизация
# После mean = 0, std = 1 у всех признаков
# Подход лучше зарекомендовал себя в линейных подходах МЛ (LinearRegression, SVM)
# Для моделей, основанных не дереве решений (DecisionTree, Bagging, RandomForest, Boosting) масштабирование данных необязательно
# Му

# %% [markdown]
# Сохранение DataFrame в файл

# %%
df2=df1.copy()

# %%
df2_cat=df2.copy()

# %%
df2_cat['Transmission'] = df2_cat['Transmission'].map({'Automatic': 1, 'Manual': 0})# в данном случае задаем словарь
# где key (ключ) - исходное значение, value (значение) - на что конкретный ключ будет заменен

# %%
df2_cat[cat_col.columns] = df2_cat[cat_col.columns].astype('category') # задаем тип

for _, column_name in enumerate(cat_col.columns): # перебираем все колонки 
    df2_cat[column_name] =  df2_cat[column_name].cat.codes
df2_cat.info() # по типам данных видно что пропали Object
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32074 entries, 0 to 32073
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Make                  32074 non-null  int8
#  1   Model                 32074 non-null  int8
#  2   Style                 32074 non-null  int8
#  3   Distance              32074 non-null  float64
#  4   Engine_capacity(cm3)  32074 non-null  float64
#  5   Fuel_type             32074 non-null  int8
#  6   Transmission          32074 non-null  int8
#  7   Price(euro)           32074 non-null  float64
#  8   Age                   32074 non-null  int64
#  9   km_year               32074 non-null  float64
#  10  class                 32074 non-null  int64
#  11  prestige              32074 non-null  int64
# dtypes: float64(4), int64(3), int8(5)
# memory usage: 1.9 MB

# %%
scaler.fit(df2_cat)
df2_cat_std = pd.DataFrame(scaler.transform(df2_cat), columns=df2_cat.columns)
df2_cat_std.head()
# Out:
#      Make   Model   Style  Distance  Engine_capacity(cm3)  Fuel_type  \
# 0  1.1499  0.4857 -1.1015    0.1624               -0.1124     0.0589
# 1  0.5721 -0.3662  1.0736   -0.5003               -0.6043    -1.0101
# 2  0.5721 -0.1106  1.0736   -0.7764               -0.6043    -1.0101
# 3  0.2832 -1.4736  1.0736    0.2176               -0.4403     0.5933
# 4 -0.0779  1.4512 -0.7908    1.3221                0.5436    -1.0101
#
#    Transmission  Price(euro)     Age  km_year   class  prestige
# 0        1.0886      -0.1814 -0.3719   0.3923  0.4483   -0.4508
# 1       -0.9186      -0.0975 -0.7908   0.2748  0.4483   -0.4508
# 2       -0.9186      -0.3073 -0.5115  -0.5354 -0.4364    0.4403
# 3       -0.9186      -0.5644  0.3261  -0.3285 -0.4364    0.4403
# 4       -0.9186      -0.6284  1.1638  -0.1718 -0.4364    1.3313

# %%
pd.set_option('display.float_format', lambda x: '%0.4f' % x)
df2_cat_std.describe()
# Out:
#             Make      Model      Style   Distance  Engine_capacity(cm3)  \
# count 32074.0000 32074.0000 32074.0000 32074.0000            32074.0000
# mean     -0.0000    -0.0000    -0.0000    -0.0000               -0.0000
# std       1.0000     1.0000     1.0000     1.0000                1.0000
# min      -1.7391    -1.8428    -2.3445    -1.9903               -2.7361
# 25%      -0.8002    -0.7921    -1.1015    -0.6328               -0.6043
# 50%       0.2110     0.2870     0.4522    -0.0033               -0.1124
# 75%       0.7888     0.7413     0.7629     0.6081                0.2156
# max       1.3666     1.7068     1.0736     3.5311                5.1351
#
#        Fuel_type  Transmission  Price(euro)        Age    km_year      class  \
# count 32074.0000    32074.0000   32074.0000 32074.0000 32074.0000 32074.0000
# mean      0.0000        0.0000      -0.0000    -0.0000    -0.0000    -0.0000
# std       1.0000        1.0000       1.0000     1.0000     1.0000     1.0000
# ...

# %%
scaler1.fit(df2_cat_std)
df2_cat_std_power = pd.DataFrame(scaler1.transform(df2_cat_std), columns=df2_cat_std.columns)
df2_cat_std_power.head()
# Out:
#      Make   Model   Style  Distance  Engine_capacity(cm3)  Fuel_type  \
# 0  1.2171  0.3942 -1.1290    0.2068                0.0099     0.1135
# 1  0.5118 -0.4932  1.2326   -0.4714               -0.5725    -1.0157
# 2  0.5118 -0.2536  1.2326   -0.7669               -0.5725    -1.0157
# 3  0.1863 -1.3742  1.2326    0.2610               -0.3692     0.6282
# 4 -0.1896  1.6713 -0.9245    1.2936                0.6531    -1.0157
#
#    Transmission  Price(euro)     Age  km_year   class  prestige
# 0        1.0886       0.1632 -0.2351   0.4672  0.4259   -0.4520
# 1       -0.9186       0.3061 -0.8113   0.3559  0.4259   -0.4520
# 2       -0.9186      -0.0786 -0.4175  -0.4906 -0.4608    0.4390
# 3       -0.9186      -0.6795  0.5188  -0.2610 -0.4608    0.4390
# 4       -0.9186      -0.8524  1.1746  -0.0928 -0.4608    1.3326

# %%
pd.set_option('display.float_format', lambda x: '%0.4f' % x)
df2_cat_std_power.describe()
# Out:
#             Make      Model      Style   Distance  Engine_capacity(cm3)  \
# count 32074.0000 32074.0000 32074.0000 32074.0000            32074.0000
# mean      0.0000    -0.0000    -0.0000    -0.0000               -0.0000
# std       1.0000     1.0000     1.0000     1.0000                1.0000
# min      -1.5882    -1.6310    -1.7841    -2.1290               -3.8422
# 25%      -0.8462    -0.8567    -1.1290    -0.6124               -0.5725
# 50%       0.1082     0.1643     0.2796     0.0420                0.0099
# 75%       0.7684     0.7077     0.7272     0.6362                0.3486
# max       1.4979     2.0479     1.2326     3.1899                3.6161
#
#        Fuel_type  Transmission  Price(euro)        Age    km_year      class  \
# count 32074.0000    32074.0000   32074.0000 32074.0000 32074.0000 32074.0000
# mean      0.0000        0.0000       0.0000    -0.0000    -0.0000    -0.0000
# std       1.0000        1.0000       1.0000     1.0000     1.0000     1.0000
# ...

# %%
mins = df2_cat.min()
maxs = df2_cat.max()
df2_norm = (df2_cat - mins) / (maxs - mins)
df2_norm.describe()
# Out:
#             Make      Model      Style   Distance  Engine_capacity(cm3)  \
# count 32074.0000 32074.0000 32074.0000 32074.0000            32074.0000
# mean      0.5600     0.5192     0.6859     0.3605                0.3476
# std       0.3220     0.2817     0.2926     0.1811                0.1270
# min       0.0000     0.0000     0.0000     0.0000                0.0000
# 25%       0.3023     0.2960     0.3636     0.2458                0.2708
# 50%       0.6279     0.6000     0.8182     0.3599                0.3333
# 75%       0.8140     0.7280     0.9091     0.4706                0.3750
# max       1.0000     1.0000     1.0000     1.0000                1.0000
#
#        Fuel_type  Transmission  Price(euro)        Age    km_year      class  \
# count 32074.0000    32074.0000   32074.0000 32074.0000 32074.0000 32074.0000
# mean      0.3780        0.4577       0.0930     0.2533     0.2962     0.6233
# std       0.3742        0.4982       0.0955     0.1433     0.1453     0.2826
# ...

# %%
df2.hist(figsize=(10,5));

# %%
df2_cat.hist(figsize=(10,10));

# %%
df2_cat_std.hist(figsize=(10,10));

# %%
df2_cat_std_power.hist(figsize=(10,10));

# %%
df2_norm.hist(figsize=(10,10));

# %%
df2_dum=df2.copy()

# %%
df2_dum=pd.get_dummies(df2_dum)
df2_dum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32074 entries, 0 to 32073
# Columns: 197 entries, Distance to Transmission_Manual
# dtypes: float64(4), int64(3), uint8(190)
# memory usage: 7.5 MB

# %%
scaler.fit(df2_dum)
df2_dum_std = pd.DataFrame(scaler.transform(df2_dum), columns=df2_dum.columns)

scaler1.fit(df2_dum_std)
df2_dum_std_power = pd.DataFrame(scaler1.transform(df2_dum_std), columns=df2_dum_std.columns)

mins = df2_dum.min()
maxs = df2_dum.max()
df2_dum_norm = (df2_dum - mins) / (maxs - mins)

# %%
df2.to_csv('/content/df2.csv',index=False)
df2_cat.to_csv('/content/df2_cat.csv',index=False)
df2_cat_std.to_csv('/content/df2_cat_std.csv',index=False)
df2_cat_std_power.to_csv('/content/df2_cat_std_power',index=False)
df2_norm.to_csv('/content/df2_norm',index=False)
df2_dum.to_csv('/content/df2_dum.csv',index=False)
df2_dum_std.to_csv('/content/df2_dum_std.csv',index=False)
df2_dum_std_power.to_csv('/content/df2_dum_std_power',index=False)
df2_dum_norm.to_csv('/content/df2_dum_norm',index=False)
